# %% [markdown]
# <a href="https://colab.research.google.com/github/richa-agarwal-de/python-machine-learning/blob/main/ML_FinalProject_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df = pd.read_csv('taxi.csv')
df.head()
# Out:
#    Priceperweek  Population  Monthlyincome  Averageparkingpermonth  \
# 0            15     1800000           5800                      50
# 1            15     1790000           6200                      50
# 2            15     1780000           6400                      60
# 3            25     1778000           6500                      60
# 4            25     1750000           6550                      60
#
#    Numberofweeklyriders
# 0                192000
# 1                190400
# 2                191200
# 3                177600
# 4                176800

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27 entries, 0 to 26
# Data columns (total 5 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Priceperweek            27 non-null     int64
#  1   Population              27 non-null     int64
#  2   Monthlyincome           27 non-null     int64
#  3   Averageparkingpermonth  27 non-null     int64
#  4   Numberofweeklyriders    27 non-null     int64
# dtypes: int64(5)
# memory usage: 1.2 KB

# %%
df_cleaned = df.drop_duplicates()
df = df_cleaned.copy()

# %%
from sklearn.model_selection import train_test_split

X = df.drop('Numberofweeklyriders',axis=1)
Y = df['Numberofweeklyriders']

X_train,X_test,Y_train,Y_test = train_test_split(X,Y,test_size=0.2,random_state=42)

print(X_train.shape)
print(Y_train.shape)
# Out:
# (21, 4)
# (21,)

# %%
import numpy as np
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# %%
model = RandomForestRegressor(random_state=42)
model.fit(X_train,Y_train)

print('training completed')
# Out:
# training completed

# %%
# making predictions
Y_pred = model.predict(X_test)

r2 = r2_score(Y_test,Y_pred)
print(r2)
# Out:
# 0.8751982761666648

# %%
# mean absolure error

mae = mean_absolute_error(Y_test,Y_pred)
print(mae)
# Out:
# 3573.493333333332

# %%
import pickle

model_filename = "random_forest_model.pkl"

with open(model_filename,'wb') as file:
  pickle.dump(model,file)

# %%
import numpy as np
int_feature = [15,180000,5800,50]
final_features = np.array(int_feature).reshape(-1,1)
print(final_features)
print(np.shape(final_features))
# Out:
# [[    15]
#  [180000]
#  [  5800]
#  [    50]]
# (4, 1)

# %%
final_features_2 = [np.array(int_feature).reshape(1,-1)]
print(final_features_2)
print(np.shape(final_features_2))
# Out:
# [array([[    15, 180000,   5800,     50]])]
# (1, 1, 4)
